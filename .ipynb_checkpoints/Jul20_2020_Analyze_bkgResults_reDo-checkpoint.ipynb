# %% [markdown]
# # Analyze the results from calculating background numbers for all configs

# %% [markdown]
# ## July 20th

# %% [markdown]
# I performed a scan (~1000 times) scrambling the position of the source for a fixed SNR cut (starting with diffuse cut), and calculated the number of events that passed all cuts, then this result was averaged by the number of times the scrambling was done. We'd like to lower the SNR cut until we get a number of backgrounds similar to that obtained in the diffuse analysis.
#
# I had to re-run imposing a new cut, since the files that Brian gave me have an outdated version of the cut

# %%
import sys
sys.path.insert(0,"/users/PCON0003/cond0068/.local/lib/python3.7/")
sys.path.append("/users/PAS0654/osu8354/ARA_cvmfs/root_build/lib/") # go to parent dir
sys.path.append("/users/PCON0003/cond0068/.local/lib/python3.7/site-packages/")
import ROOT
import math
import numpy as np
from ROOT import TH1D,TF1, gRandom, gPad, gStyle
import matplotlib.pyplot as plt
from ROOT import TChain, TSelector, TTree
import os
import matplotlib.colors as mcolors
import scipy
from matplotlib.colors import LogNorm
import pandas as pd

# %%
f = ROOT.TFile.Open("/users/PAS0654/osu8354/ARA_cvmfs/source/AraRoot/analysis/files/source_optimization/c1/bkg_random_SNR_scan_config1_seed56.root")
f.ls()
tree = f.Get("SNR_scan_c1")
tree.Print()
# Out:
# TFile**		/users/PAS0654/osu8354/ARA_cvmfs/source/AraRoot/analysis/files/source_optimization/c1/bkg_random_SNR_scan_config1_seed56.root
#  TFile*		/users/PAS0654/osu8354/ARA_cvmfs/source/AraRoot/analysis/files/source_optimization/c1/bkg_random_SNR_scan_config1_seed56.root
#   KEY: TTree	SNR_scan_c1;1	SNR_scan_c1
#   KEY: TH2D	;2	H Data
#   KEY: TH2D	;1	V Data, phi = -40.002134, theta = 49.755645
# ******************************************************************************
# *Tree    :SNR_scan_c1: SNR_scan_c1                                            *
# *Entries :        5 : Total =            3053 bytes  File  Size =       1167 *
# *        :          : Tree compression factor =   1.32                       *
# ******************************************************************************
# *Br    0 :phi       : phi/D                                                  *
# *Entries :        5 : Total  Size=        602 bytes  File Size  =        117 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br    1 :theta     : theta/D                                                *
# *Entries :        5 : Total  Size=        612 bytes  File Size  =        119 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br    2 :numPassAll : numPassAll[6]/I                                       *
# *Entries :        5 : Total  Size=        715 bytes  File Size  =        129 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.58     *
# *............................................................................*
# *Br    3 :SNR_intercept : SNR_intercept[6]/F                                 *
# *Entries :        5 : Total  Size=        730 bytes  File Size  =        124 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.67     *
# *............................................................................*

# %%
phi = tree.AsMatrix(["theta"])
theta = tree.AsMatrix(["phi"])
numPassAll = []
SNR_intercept = []
tree.GetEvent(0)
SNR_intercept = np.array(tree.SNR_intercept).reshape(6,4)[:,0]
for i in range(0, tree.GetEntries()):
    tree.GetEvent(i)
#     phi.append(tree.phi)
#     theta.append(tree.theta)
#     for j in range(0,5):
#         numPassAll[j].append(tree.numPassAll[j])
    
    numPassAll.append(np.array(tree.numPassAll).reshape(6,4)[:,0])

# %%
colNames = ["phi", 'theta'] + ["%.1f" % x for x in SNR_intercept]
colNames
# Out:
# ['phi', 'theta', '20.0', '19.5', '19.0', '18.5', '18.0', '17.5']

# %%
plt.axhline(5E-2, ls="--", c="C1", label="Diffuse $N_{bkg}$ SNR cut = 20.6")
# plt.axvline(20.6, ls="--", c="C2", label="Diffuse SNR cut")

plt.plot(bkg.snr, bkg.bkg)
plt.yscale('log')
# plt.ylim(0.01,1)
plt.xlabel("SNR-intercept cut", fontsize=14)
plt.ylabel("$N_{bkg}$", fontsize=14)
plt.title("SNR scan",fontsize=18)
plt.legend()
plt.tight_layout()
# plt.savefig("./plots/scan_yinterc_scrambled_source.png", dpi=150)

# %%
#colNames = ["phi", 'theta', '20.6', '20.4', '20.2', '20.0', '19.8', '19.6']
# colNames = ["phi", 'theta', '19.5', '19', '18.5', '18', '17.5', '17']
# colNames = ["phi", 'theta', '19', '18.9', '18.8', '18.7', '18.6', '18.5']
colNames = ["phi", 'theta', "20", "19.5", "19", "18.5", "18", "17.5"]

for i in range(1,6):
    SNR = pd.read_csv("/users/PAS0654/osu8354/ARA_cvmfs/source/AraRoot/analysis/files/source_optimization/bkg_random_SNR_scan_config%i.csv"%i, names=colNames)
    SNR = SNR.dropna()
    for col in SNR.columns[2:]:
#     print(SNR[col].tail())
        SNR.loc[SNR[col]<0, col]=0    
    plt.figure()
#     plt.hist2d(SNR.phi,np.cos(np.deg2rad(SNR.theta+90)), weights=SNR["18.5"], bins=20)
    plt.hist2d(SNR.phi,SNR.theta, weights=SNR["19"], bins=20)
    cbar = plt.colorbar()
    cbar.set_label(label='$N_{passed}$',weight='bold', fontsize=14)
#     plt.scatter(SNR.phi, np.cos(np.deg2rad(SNR.theta+90)), s=1, c="w", label = "Source position")
    plt.scatter(SNR.phi, SNR.theta, s=1, c="w", label = "Source position")

    # plt.axvline(20.6, ls="--", c="C2", label="Diffuse SNR cut")

    plt.xlabel("$\phi$", fontsize=14)
    plt.ylabel("$\cos(\\theta$)", fontsize=14)
    plt.title("Position dependence, config %i"%i,fontsize=18)
    legend = plt.legend(loc='lower right' , fancybox=True, facecolor='k', markerscale=4, shadow=True)
    plt.setp(legend.get_texts(), color='w')
    plt.tight_layout()
#     plt.savefig("./plots/pos_dependence_c%i.png"%i, dpi=150)

# %% [markdown]
# ## Look at angle distribution as a function of background estimates

# %%
plt.scatter(SNR.phi, np.cos(np.deg2rad(SNR.theta)))
# plt.scatter(SNR.phi,np.deg2rad(SNR.theta))
plt.xlabel("$\phi$")
plt.ylabel("$\cos(\\theta$)")
# Out:
# Text(0,0.5,'$\\cos(\\theta$)')

# %% [markdown]
# ## Comments

# %% [markdown]
# The files that Brian gave me are outdated, so I have to rerun everything and set the surface cut manually. Will re-do the analysis in a new notebook

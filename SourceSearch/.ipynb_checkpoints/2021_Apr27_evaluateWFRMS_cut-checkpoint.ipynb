# %% [markdown]
# # Explore and compare save vals file

# %% [markdown]
# ### Apr 23, 2021

# %% [markdown]
# ## Code

# %%
import sys
import csv
# sys.path.insert(0,"/users/PCON0003/cond0068/.local/lib/python3.7/")
sys.path.append("/users/PAS0654/osu8354/ARA_cvmfs/root_build/lib/") # go to parent dir
sys.path.append("/users/PCON0003/cond0068/.local/lib/python3.7/site-packages/")
# sys.path.append("/users/PCON0003/cond0068/pyrex_sims/fromBen/thesis_work/pyrex-custom/analysis/custom/analysis/")
import ROOT
import math
import numpy as np
from ROOT import TH1D,TF1, gRandom, gPad, gStyle
import matplotlib as mpl
import matplotlib.pyplot as plt
from ROOT import TChain, TSelector, TTree
import os
import matplotlib.colors as mcolors
import scipy
from matplotlib.colors import LogNorm
import pandas as pd
import seaborn as sns
# %matplotlib inline
# sys.path.insert(1, "/users/PAS0654/osu8354/ARA_cvmfs/source/AraRoot/analysis/ARA_analysis/SourceSearch")
# import deDisperse_util as util
import matplotlib.colors as colors

my_path_plots = os.path.abspath("./plots/")
import re
# Out:
# Welcome to JupyROOT 6.18/04

# %%
# mpl.use('agg') 
mpl.rcParams['text.usetex'] = True
mpl.rcParams['text.latex.unicode'] = True
mpl.rcParams['mathtext.rm'] = 'Times New Roman'
mpl.rcParams['mathtext.it'] = 'Times New Roman:italic'
mpl.rcParams['mathtext.bf'] = 'Times New Roman:bold'

mpl.rc('font', family='serif', size=12)
mpl.rcParams['xtick.labelsize'] = 14
mpl.rcParams['ytick.labelsize'] = 14
mpl.rcParams['xtick.major.size'] = 5
mpl.rcParams['ytick.major.size'] = 5

mpl.rcParams['axes.titlesize'] = 18
mpl.rcParams['axes.labelsize'] = 18
# mpl.rc('font', size=16)
mpl.rc('axes', titlesize=20)

current_palette = sns.color_palette('colorblind', 10)
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Get data

# %%
# /users/PAS0654/osu8354/ARA_cvmfs/source/AraRoot/analysis/cutvals_drop_FiltSurface_CWThresh2.0_snrbins_0_0_wfrmsvals_-1.3_-1.4_run_3228_new.root

fOld = ROOT.TFile.Open("/fs/project/PAS0654/ARA_DATA/A23/10pct_redo/ValsForCuts/A2/c1/cutvals_drop_FiltSurface_snrbins_0_0_wfrmsvals_-1.3_-1.4_run_3226.root", "read")
tNewAll_old = fOld.Get("AllTree")
tNewV_old = fOld.Get("VTree")
tNewH_old = fOld.Get("HTree")

fNew = ROOT.TFile.Open("/users/PAS0654/osu8354/ARA_cvmfs/source/AraRoot/analysis/cutvals_drop_FiltSurface_CWThresh2.0_snrbins_0_0_wfrmsvals_-1.3_-1.4_run_3226.root", "read")
# fNew = ROOT.TFile.Open("/fs/project/PAS0654/ARA_DATA/A23/10pct_redo/ValsForCuts/A2/c1/cutvals_drop_FiltSurface_snrbins_0_0_wfrmsvals_-1.3_-1.4_run_3226.root", "read")

tNewAll = fNew.Get("AllTree")
tNewV = fNew.Get("VTree")
tNewH= fNew.Get("HTree")

#Cw tree
fCW = ROOT.TFile.Open("/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix//CWID/A2/by_config/c1/CWID_station_2_run_3226.root", "read")
fCW_old = ROOT.TFile.Open("/fs/project/PAS0654/ARA_DATA/A23/10pct_redo/CWID/A2/by_config/c1/CWID_station_2_run_3226.root", "read")

tCW = fCW.Get("NewCWTree")
tCW_old = fCW_old.Get("NewCWTree")

# %% [markdown]
# ## Phase variance

# %%
SNR_before = []
SNR_after =[]
count = 0
numEntries = tNewV.GetEntries()
for event in range(numEntries):
    tNewAll.GetEntry(event)
    tNewV.GetEntry(event)
    tNewH.GetEntry(event)
    tNewAll_old.GetEntry(event)
    tNewV_old.GetEntry(event)
    tNewH_old.GetEntry(event)
    tCW.GetEntry(event)
    tCW_old.GetEntry(event)

#     if(tNewV.Refilt_V or tNewH.Refilt_H):
    if(tNewAll.CW):
        count+=1
#         print("EvNum: %i"%tNewAll.eventNumber)
#         print("Old")
#         print("Sigmas_old:%s"%tCW_old.badSigmas_back)
#         print("freqs_old:%s"%tCW_old.badFreqs_back)

#         print()
#         print("New")
#         print("Sigmas_new:%s"%tCW.badSigmas_back)
#         print("freqs_new:%s"%tCW.badFreqs_back)
        print()
        
#         print(np.array(tCW.badFreqs_back[0])[0])

# %%
count
# Out:
# 10

# %%
SNR_before = []
SNR_after =[]
count = 0
numEntries = tNewV.GetEntries()
for event in range(numEntries):
    tNewAll.GetEntry(event)
    tNewV.GetEntry(event)
    tNewH.GetEntry(event)
    tNewAll_old.GetEntry(event)
    tNewV_old.GetEntry(event)
    tNewH_old.GetEntry(event)
    tCW.GetEntry(event)
    tCW_old.GetEntry(event)

#     if(tNewV_old.Refilt_V or tNewH_old.Refilt_H):
    if(tNewAll_old.CW):
        count+=1
#         print("EvNum: %i"%tNewAll.eventNumber)
#         print("Old")
#         print("Sigmas_old:%s"%tCW_old.badSigmas_back)
#         print("freqs_old:%s"%tCW_old.badFreqs_back)

#         print()
#         print("New")
#         print("Sigmas_new:%s"%tCW.badSigmas_back)
#         print("freqs_new:%s"%tCW.badFreqs_back)
#         print()
        
#         print(np.array(tCW.badFreqs_back[0])[0])

# %%
count
# Out:
# 114

# %% [markdown]
# ## Peaks over baselines

# %%
SNR_before = []
SNR_after =[]
count = 0
numEntries = tNewV.GetEntries()
for event in range(numEntries):
    tNewAll.GetEntry(event)
    tNewV.GetEntry(event)
    tNewH.GetEntry(event)
    tNewAll_old.GetEntry(event)
    tNewV_old.GetEntry(event)
    tNewH_old.GetEntry(event)
    tCW.GetEntry(event)
    tCW_old.GetEntry(event)

    if(tNewV.Refilt_V or tNewH.Refilt_H):
        print("EvNum: %i"%tNewAll.eventNumber)
        print("Old")
#         print("Sigmas_old:%s"%tCW_old.badSigmas_back)
        print("freqs_old:%s"%tCW_old.badFreqs_baseline)

        print()
        print("New")
#         print("Sigmas_new:%s"%tCW.badSigmas_back)
        print("freqs_new:%s"%tCW.badFreqs_baseline)
        print()
        
#         print(np.array(tCW.badFreqs_back[0])[0])
# Out:
# EvNum: 6969
# Old
# freqs_old:{ { 401.34375, 402.32031 }, {} }
#
# New
# freqs_new:{ { 401.34375, 402.32031 }, {} }
#
# EvNum: 7446
# Old
# freqs_old:{ { 401.34375, 402.32031, 403.29688 }, {} }
#
# New
# freqs_new:{ { 401.34375, 402.32031, 403.29688 }, {} }
#
# EvNum: 8299
# Old
# freqs_old:{ { 401.34375, 402.32031, 406.22656 }, {} }
#
# New
# freqs_new:{ { 401.34375, 402.32031 }, {} }
#
# EvNum: 8500
# Old
# freqs_old:{ { 401.34375, 402.32031 }, {} }
#
# New
# freqs_new:{ { 401.34375, 402.32031 }, {} }
#
# EvNum: 11873
# Old
# freqs_old:{ { 401.34375, 402.32031 }, {} }
#
# New
# freqs_new:{ {}, {} }
#
# EvNum: 12935
# Old
# freqs_old:{ {}, {} }
#
# New
# freqs_new:{ {}, {} }
#
# EvNum: 16959
# Old
# freqs_old:{ {}, {} }
#
# New
# freqs_new:{ {}, {} }
#
# EvNum: 19526
# Old
# freqs_old:{ {}, {} }
#
# New
# freqs_new:{ {}, {} }
#
# EvNum: 19614
# Old
# freqs_old:{ {}, {} }
#
# New
# freqs_new:{ {}, {} }
#
# EvNum: 22434
# Old
# freqs_old:{ {}, {} }
#
# New
# freqs_new:{ {}, {} }

# %%
SNR_before = []
SNR_after =[]
count = 0
numEntries = tNewV.GetEntries()
for event in range(numEntries):
    tNewAll.GetEntry(event)
    tNewV.GetEntry(event)
    tNewH.GetEntry(event)
    tNewAll_old.GetEntry(event)
    tNewV_old.GetEntry(event)
    tNewH_old.GetEntry(event)
    tCW.GetEntry(event)
    tCW_old.GetEntry(event)

    if(tNewV_old.Refilt_V or tNewH_old.Refilt_H):
        print("EvNum: %i"%tNewAll.eventNumber)
        print("Old")
#         print("Sigmas_old:%s"%tCW_old.badSigmas_back)
        print("freqs_old:%s"%tCW_old.badFreqs_baseline)

        print()
        print("New")
#         print("Sigmas_new:%s"%tCW.badSigmas_back)
        print("freqs_new:%s"%tCW.badFreqs_baseline)
        print()
        
#         print(np.array(tCW.badFreqs_back[0])[0])
# Out:
# EvNum: 5934
# Old
# freqs_old:{ {}, {} }
#
# New
# freqs_new:{ {}, {} }
#
# EvNum: 6410
# Old
# freqs_old:{ {}, {} }
#
# New
# freqs_new:{ {}, {} }
#
# EvNum: 6438
# Old
# freqs_old:{ {}, {} }
#
# New
# freqs_new:{ {}, {} }
#
# EvNum: 6446
# Old
# freqs_old:{ { 401.34375 }, {} }
#
# New
# freqs_new:{ { 401.34375 }, {} }
#
# EvNum: 6518
# Old
# freqs_old:{ { 401.34375, 402.32031 }, {} }
#
# New
# freqs_new:{ { 401.34375, 402.32031 }, {} }
#
# EvNum: 6642
# Old
# freqs_old:{ { 401.34375 }, {} }
#
# New
# freqs_new:{ { 401.34375, 402.32031 }, {} }
#
# EvNum: 6664
# Old
# freqs_old:{ { 401.34375, 402.32031 }, {} }
#
# New
# freqs_new:{ { 401.34375, 402.32031 }, {} }
#
# EvNum: 6817
# Old
# freqs_old:{ { 401.34375, 402.32031 }, {} }
#
# New
# freqs_new:{ { 401.34375, 402.32031 }, {} }
#
# EvNum: 6887
# Old
# freqs_old:{ { 401.34375, 402.32031 }, {} }
#
# New
# freqs_new:{ { 400.36719, 401.34375, 402.32031 }, {} }
#
# EvNum: 6969
# Old
# freqs_old:{ { 401.34375, 402.32031 }, {} }
#
# New
# ...

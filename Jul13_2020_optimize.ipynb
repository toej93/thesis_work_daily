# %% [markdown]
# # Fixing optimization code

# %% [markdown]
# ## July 13th

# %% [markdown]
# I had to fix Brian's optimization code, since it was outdate with variable names and locations. It is noow working. I was able to optimize using the approach that we discussed, randomize the direction of the source, and then do the optimization, and then repeat the same process with different randomized source coordinates. I did this 10 times, for a bunch of runs, as I was debugging it. I plan to do it more times tomorrow, and using the 10% data. I'm leaving some plots below of the optimization results for different randomized source coordinates.

# %% [markdown]
# ![lkn](/users/PAS0654/osu8354/ARA_cvmfs/source/AraRoot/analysis/plots/optimize/A2_config1_702706Events_SNRvsCorr_0.png)

# %% [markdown]
# <img src="/users/PAS0654/osu8354/ARA_cvmfs/source/AraRoot/analysis/plots/optimize/A2_config1_702706Events_SNRvsCorr_0.png" width=60 height=60 />

# %%
from IPython.display import Image
Image("/users/PAS0654/osu8354/ARA_cvmfs/source/AraRoot/analysis/plots/optimize/A2_config1_Pol0_Optimization_RCutSlope-620.0000_0.png")

# %%
Image("/users/PAS0654/osu8354/ARA_cvmfs/source/AraRoot/analysis/plots/optimize/A2_config1_Pol0_Optimization_RCutSlope-620.0000_1.png")

# %%
Image("/users/PAS0654/osu8354/ARA_cvmfs/source/AraRoot/analysis/plots/optimize/A2_config1_Pol0_Optimization_RCutSlope-620.0000_2.png")

# %%
Image("/users/PAS0654/osu8354/ARA_cvmfs/source/AraRoot/analysis/plots/optimize/A2_config1_Pol0_Optimization_RCutSlope-620.0000_3.png")

# %%
Image("/users/PAS0654/osu8354/ARA_cvmfs/source/AraRoot/analysis/plots/optimize/A2_config1_Pol0_Optimization_RCutSlope-620.0000_4.png")
